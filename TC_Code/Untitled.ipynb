# %%
import pandas as pd

# %%
df=pd.read_excel(r"E:\BB TESTING\Finglide\Finglide TestReport_10102020 - Copy.xlsx")
df=df[7:]
df=list(df["Application Name"])
df
# Out:
# ['TC_01_Installation',
#  'TC_02_Intro Screen',
#  'TC_03_Intro Screen_Skip button',
#  'TC_04_Intro Screen_Next button',
#  'TC_05_Intro Screen_Swipe',
#  'TC_06_Language',
#  'TC_07_ -> Button',
#  'TC_08_LoginPage',
#  'TC_09_User Name Textbox',
#  'TC_10_Password Textbox',
#  'TC_11_Submit Button',
#  'TC_12_Login Validtion_Invalid Username_Valid Password',
#  'TC_13_Login Validtion_valid Username_Invalid Password',
#  'TC_14_Login Validtion_valid Username_Blank Password',
#  'TC_15_Login Validtion_Blank Username_Valid Password',
#  'TC_16_Login Validtion_Blank Username_Blank Password',
#  'TC_17_Login Validation_valid username and valid password',
#  'TC_18_Login_Face Recognition Registered Face',
#  'TC_18_Login_Face Recognition Registered Face_Cap/Hat',
#  'TC_18_Login_Face Recognition Registered Face_Eyewears',
#  'TC_19_Login_Face Recognition Unregistered Face',
#  'TC_20_Login_Voice Bonding_Unregistered phrase',
#  'TC_21_Login_Voice Bonding_Unregistered voice',
# ...

# %%
listxx=[]
for i in range(1,len(df)+1):
    str1=str(df[i-1])
    str2=str1.replace(str1[:5],str("TC_"+"{:0>2}".format(str(i))+""))
    listxx.append(str2)

# %%
listxx
# Out:
# ['TC_01_Installation',
#  'TC_02_Intro Screen',
#  'TC_03_Intro Screen_Skip button',
#  'TC_04_Intro Screen_Next button',
#  'TC_05_Intro Screen_Swipe',
#  'TC_06_Language',
#  'TC_07_ -> Button',
#  'TC_08_LoginPage',
#  'TC_09_User Name Textbox',
#  'TC_10_Password Textbox',
#  'TC_11_Submit Button',
#  'TC_12_Login Validtion_Invalid Username_Valid Password',
#  'TC_13_Login Validtion_valid Username_Invalid Password',
#  'TC_14_Login Validtion_valid Username_Blank Password',
#  'TC_15_Login Validtion_Blank Username_Valid Password',
#  'TC_16_Login Validtion_Blank Username_Blank Password',
#  'TC_17_Login Validation_valid username and valid password',
#  'TC_18_Login_Face Recognition Registered Face',
#  'TC_19_Login_Face Recognition Registered Face_Cap/Hat',
#  'TC_20_Login_Face Recognition Registered Face_Eyewears',
#  'TC_21_Login_Face Recognition Unregistered Face',
#  'TC_22_Login_Voice Bonding_Unregistered phrase',
#  'TC_23_Login_Voice Bonding_Unregistered voice',
# ...

# %%
xls=pd.DataFrame({'CODES':listxx})
xls
xls.to_excel("test.xlsx")
